# %% [markdown]
# ### Install Libraries

# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
# !pip install selenium

import requests
from bs4 import BeautifulSoup
import pandas as pd
from os import stat
from time import sleep
from selenium import webdriver
# Out:
# Requirement already satisfied: requests in c:\users\cedmu\anaconda3\lib\site-packages (2.28.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cedmu\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cedmu\anaconda3\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cedmu\anaconda3\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cedmu\anaconda3\lib\site-packages (from requests) (3.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\cedmu\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cedmu\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: pandas in c:\users\cedmu\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cedmu\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cedmu\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\cedmu\anaconda3\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cedmu\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\cedmu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: selenium in c:\users\cedmu\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\cedmu\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\cedmu\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio~=0.17 in c:\users\cedmu\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\cedmu\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\cedmu\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\cedmu\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\cedmu\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\cedmu\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\cedmu\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: cffi>=1.14 in c:\users\cedmu\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: sortedcontainers in c:\users\cedmu\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\cedmu\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\cedmu\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\cedmu\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\cedmu\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\cedmu\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# ### Iterate through NBA seasons

# %%
years = range(1991, 2022) # Years 1991-2021

# %%
url_start = "https://www.basketball-reference.com/awards/awards_{}.html"

# %%
for year in years:
    url = url_start.format(year)
    
    # Anti-timeout
    if stat("mvp/{}.html".format(year)).st_size != 0:
        print(year, "exists and is not empty.")
        continue
    else: 
        data = requests.get(url)

        with open("mvp/{}.html".format(year), "w+", encoding="utf-8") as f:
                f.write(data.text)
        
        # Anti-timeout
        sleep(2)
# Out:
# 1991 exists and is not empty.
# 1992 exists and is not empty.
# 1993 exists and is not empty.
# 1994 exists and is not empty.
# 1995 exists and is not empty.
# 1996 exists and is not empty.
# 1997 exists and is not empty.
# 1998 exists and is not empty.
# 1999 exists and is not empty.
# 2000 exists and is not empty.
# 2001 exists and is not empty.
# 2002 exists and is not empty.
# 2003 exists and is not empty.
# 2004 exists and is not empty.
# 2005 exists and is not empty.
# 2006 exists and is not empty.
# 2007 exists and is not empty.
# 2008 exists and is not empty.
# 2009 exists and is not empty.
# 2010 exists and is not empty.
# 2011 exists and is not empty.
# 2012 exists and is not empty.
# 2013 exists and is not empty.
# 2014 exists and is not empty.
# 2015 exists and is not empty.
# 2016 exists and is not empty.
# 2017 exists and is not empty.
# 2018 exists and is not empty.
# 2019 exists and is not empty.
# 2020 exists and is not empty.
# 2021 exists and is not empty.

# %% [markdown]
# ### Parse with BeautifulSoup

# %%
dfs = []

for year in years:
    with open("mvp/{}.html".format(year), "r", encoding="utf-8") as f:
        page = f.read()
    soup = BeautifulSoup(page, "html.parser")

    # Remove extraneous info
    try:
        soup.find('tr', class_="over_header").decompose()
    except:
        print(year, 'skipped.')
        continue

    # Populate list of dataframes
    mvp_table = soup.find(id="mvp")
    mvp = pd.read_html(str(mvp_table))[0]
    mvp["Year"] = year

    dfs.append(mvp)

# %% [markdown]
# ### Concat into one DataFrame

# %%
mvps = pd.concat(dfs)

# %%
mvps.head()
# Out:
#   Rank           Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP
# 0    1   Michael Jordan   27  CHI   77.0    891.0      960  0.928  82  37.0  \
# 1    2    Magic Johnson   31  LAL   10.0    497.0      960  0.518  79  37.1
# 2    3   David Robinson   25  SAS    6.0    476.0      960  0.496  82  37.7
# 3    4  Charles Barkley   27  PHI    2.0    222.0      960  0.231  67  37.3
# 4    5      Karl Malone   27  UTA    0.0    142.0      960  0.148  82  40.3
#
#    ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  Year
# 0  ...   6.0   5.5  2.7  1.0  0.539  0.312  0.851  20.3  0.321  1991
# 1  ...   7.0  12.5  1.3  0.2  0.477  0.320  0.906  15.4  0.251  1991
# 2  ...  13.0   2.5  1.5  3.9  0.552  0.143  0.762  17.0  0.264  1991
# 3  ...  10.1   4.2  1.6  0.5  0.570  0.284  0.722  13.4  0.258  1991
# 4  ...  11.8   3.3  1.1  1.0  0.527  0.286  0.770  15.5  0.225  1991
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Save to CSV

# %%
mvps.to_csv("mvps.csv")

# %% [markdown]
# ### Initialize Selenium WebDriver

# %%
driver = webdriver.Chrome(executable_path="/Users/CEdmu/Jupyter/NBA Stats/chromedriver")
# Out:
# C:\Users\CEdmu\AppData\Local\Temp\ipykernel_8024\2479448616.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="/Users/CEdmu/Jupyter/NBA Stats/chromedriver")

# %% [markdown]
# ### Iterate through NBA Players

# %%
player_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"

for year in years:
    url = player_stats_url.format(year)

    driver.get(url)
    
    # Javascript handling
    driver.execute_script("window.scrollTo(1,10000)")
    sleep(2)

    html = driver.page_source
    
    with open("player/{}.html".format(year), "w+", encoding="utf-8") as f:
        f.write(html)
    
    # Anti-timeout
    sleep(2)

# Close Webdriver
driver.quit()

# %% [markdown]
# ### Parse with BeautifulSoup

# %%
dfs = []
for year in years:
    with open("player/{}.html".format(year), "r", encoding="utf-8") as f:
        page = f.read()

    soup = BeautifulSoup(page, "html.parser")

    # Remove extraneous info
    try:
        soup.find('tr', class_="thead").decompose()
    except:
        print(year, 'skipped.')
        continue

    # Populate list of dataframes
    player_table = soup.find(id="per_game_stats")
    player = pd.read_html(str(player_table))[0]
    player["Year"] = year 
    dfs.append(player)

# %%
players = pd.concat(dfs)

# %%
players
# Out:
#       Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  ORB
# 0      1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  ...  0.6  \
# 1      2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  ...  0.5
# 2      3          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  ...  2.1
# 3      4       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  ...  0.9
# 4      5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  ...  1.7
# ..   ...                 ...  ..  ..  ...  ..  ..   ...  ...   ...  ...  ...
# 725  536        Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3  ...  1.0
# 726  537      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  ...  2.5
# 727  538          Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  ...  0.6
# 728  539         Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  ...  2.5
# 729  540         Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  ...  2.6
#
#      DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0    1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1    1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2    3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3    3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4    3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ..   ...  ...   ...  ...  ...  ...  ...   ...   ...
# 725  2.9  3.9   3.6  1.6  0.4  1.3  1.1  10.0  2021
# 726  3.8  6.2   4.3  1.1  0.6  2.0  2.2  12.1  2021
# 727  3.3  3.9   9.4  0.8  0.2  4.1  1.8  25.3  2021
# 728  4.4  6.8   1.8  0.6  0.4  1.1  2.5   9.4  2021
# 729  4.6  7.2   1.3  0.3  0.9  1.1  2.6   9.0  2021
#
# [18044 rows x 31 columns]

# %% [markdown]
# ### Save to CSV

# %%
players.to_csv("players.csv")

# %% [markdown]
# ### Iterate through NBA teams

# %%
team_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_standings.html"

# %%
for year in years:
    url = team_stats_url.format(year)

    data = requests.get(url)

    with open("team/{}.html".format(year), "w+", encoding="utf-8") as f:
        f.write(data.text)
        
    # Anti-timeout
    sleep(2)

# %% [markdown]
# ### Parse with BeautifulSoup

# %%
dfs = []
for year in years:
    with open("team/{}.html".format(year), "r", encoding="utf-8") as f:
        page = f.read()

    soup = BeautifulSoup(page, "html.parser")

    # Remove extraneous info
    try:
        soup.find('tr', class_="thead").decompose()
    except:
        print(year, 'skipped.')
        continue

    # Populate list of dataframes
    team_table = soup.find(id="divs_standings_E")
    team = pd.read_html(str(team_table))[0]
    team["Year"] = year 
    team["Team"] = team["Eastern Conference"]
    del team ["Eastern Conference"]
    dfs.append(team)

    # Remove extraneous info
    try:
        soup.find('tr', class_="thead").decompose()
    except:
        print(year, 'skipped.')
        continue

    # Populate list of dataframes
    team_table = soup.find(id="divs_standings_W")
    team = pd.read_html(str(team_table))[0]
    team["Year"] = year 
    team["Team"] = team["Western Conference"]
    del team ["Western Conference"]
    dfs.append(team)

# %%
teams = pd.concat(dfs)

# %%
teams
# Out:
#      W   L  W/L%    GB   PS/G   PA/G    SRS  Year                  Team
# 0   56  26  .683     —  111.5  105.7   5.22  1991       Boston Celtics*
# 1   44  38  .537  12.0  105.4  105.6  -0.39  1991   Philadelphia 76ers*
# 2   39  43  .476  17.0  103.1  103.3  -0.43  1991      New York Knicks*
# 3   30  52  .366  26.0  101.4  106.4  -4.84  1991    Washington Bullets
# 4   26  56  .317  30.0  102.9  107.5  -4.53  1991       New Jersey Nets
# ..  ..  ..   ...   ...    ...    ...    ...   ...                   ...
# 13  42  30  .583     —  112.4  110.2   2.26  2021     Dallas Mavericks*
# 14  38  34  .528   4.0  113.3  112.3   1.07  2021    Memphis Grizzlies*
# 15  33  39  .458   9.0  111.1  112.8  -1.58  2021     San Antonio Spurs
# 16  31  41  .431  11.0  114.6  114.9  -0.20  2021  New Orleans Pelicans
# 17  17  55  .236  25.0  108.8  116.7  -7.50  2021       Houston Rockets
#
# [1033 rows x 9 columns]

# %% [markdown]
# ### Save to CSV

# %%
teams.to_csv("teams.csv")
